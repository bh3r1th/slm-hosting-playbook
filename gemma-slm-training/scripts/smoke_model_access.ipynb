# %% [markdown]
# ### This is needed to run the code on the Google Colab GPU.

# %%
import os
os.environ["HF_TOKEN"] = "hf_your_token_here"

# %%
import os, torch
from huggingface_hub import login
from transformers import AutoModelForCausalLM, AutoTokenizer

# --- Auth ---
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")
login(token=os.environ["HF_TOKEN"])

# --- Load model ---
model_id = "google/gemma-3-1b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    dtype=torch.float16,
    device_map="auto"
)
model.eval()

print("GPU:", torch.cuda.get_device_name(0))

# --- Generate ---
prompt = "Write a one-sentence summary of why fine-tuning helps."
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

with torch.no_grad():
    outputs = model.generate(**inputs, max_new_tokens=60)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# GPU: NVIDIA A100-SXM4-40GB
# Write a one-sentence summary of why fine-tuning helps.
#
# Fine-tuning allows a pre-trained model to specialize in a specific task by adapting its learned representations to the nuances of the new dataset, resulting in improved accuracy and efficiency compared to training from scratch.
#
# ---
#
# Do you want me to expand on any particular aspect of this summary, such as
