# %%
# !git clone https://github.com/bh3r1th/slm-hosting-playbook.git
# Out:
# Cloning into 'slm-hosting-playbook'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 200 (delta 22), reused 26 (delta 11), pack-reused 158 (from 2)
# Receiving objects: 100% (200/200), 6.78 MiB | 14.77 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd /content/slm-hosting-playbook/gemma-slm-training
# Out:
# /content/slm-hosting-playbook/gemma-slm-training

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls -lah /content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup
# !ls -lah /content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup/gemma-3-1b-it-lora-20260114-034307 | head
# Out:
# total 16K
# drwx------ 2 root root 4.0K Jan 14 03:24 gemma-3-1b-it-lora-20260114-032410
# drwx------ 2 root root 4.0K Jan 14 03:36 gemma-3-1b-it-lora-20260114-032533
# drwx------ 2 root root 4.0K Jan 14 03:40 gemma-3-1b-it-lora-20260114-034030
# drwx------ 2 root root 4.0K Jan 14 03:43 gemma-3-1b-it-lora-20260114-034307
# -rw------- 1 root root    0 Jan 14 03:42 .gitkeep
# total 63M
# -rw------- 1 root root 1.1K Jan 14 09:19 adapter_config.json
# -rw------- 1 root root  25M Jan 14 09:19 adapter_model.safetensors
# -rw------- 1 root root   35 Jan 14 09:19 added_tokens.json
# -rw------- 1 root root 1.5K Jan 14 09:19 chat_template.jinja
# drwx------ 2 root root 4.0K Jan 14 04:39 checkpoint-1000
# drwx------ 2 root root 4.0K Jan 14 04:50 checkpoint-1200
# drwx------ 2 root root 4.0K Jan 14 05:01 checkpoint-1400
# drwx------ 2 root root 4.0K Jan 14 05:13 checkpoint-1600
# drwx------ 2 root root 4.0K Jan 14 05:24 checkpoint-1800

# %%
# %cd /content/slm-hosting-playbook/gemma-slm-training
# !mkdir -p artifacts
# !rsync -a /content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup/gemma-3-1b-it-lora-20260114-034307/ \
  artifacts/gemma-3-1b-it-lora-20260114-034307/
# Out:
# /content/slm-hosting-playbook/gemma-slm-training

# %%
# !cp -r artifacts/gemma-3-1b-it-lora-20260114-034307/checkpoint-6001/* \
  artifacts/gemma-3-1b-it-lora-20260114-034307/ || true

# %%
# !python scripts/export_artifacts.py
# Out:
# 2026-01-15 03:18:24.314889: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-15 03:18:24.319728: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-15 03:18:24.333777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768447104.358325    2284 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768447104.365394    2284 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd /content/slm-hosting-playbook/gemma-slm-training
# !ls -lah artifacts/PHASE2_MODEL_POINTER.txt
# !cat artifacts/PHASE2_MODEL_POINTER.txt
# Out:
# /content/slm-hosting-playbook/gemma-slm-training
# -rw-r--r-- 1 root root 142 Jan 15 03:18 artifacts/PHASE2_MODEL_POINTER.txt
# ADAPTER_PATH=/content/slm-hosting-playbook/gemma-slm-training/artifacts/gemma-3-1b-it-lora-20260114-034307
# BASE_MODEL_ID=google/gemma-3-1b-it

# %%
# !cp artifacts/PHASE2_MODEL_POINTER.txt .
# !ls -lah PHASE2_MODEL_POINTER.txt
# !cat PHASE2_MODEL_POINTER.txt
# Out:
# -rw-r--r-- 1 root root 142 Jan 15 03:19 PHASE2_MODEL_POINTER.txt
# ADAPTER_PATH=/content/slm-hosting-playbook/gemma-slm-training/artifacts/gemma-3-1b-it-lora-20260114-034307
# BASE_MODEL_ID=google/gemma-3-1b-it

# %%
# %cd /content/slm-hosting-playbook/gemma-slm-training/artifacts

# !sed -i 's|^ADAPTER_PATH=.*|ADAPTER_PATH=/content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup/gemma-3-1b-it-lora-20260114-034307|' PHASE2_MODEL_POINTER.txt

# !cat PHASE2_MODEL_POINTER.txt
# Out:
# /content/slm-hosting-playbook/gemma-slm-training/artifacts
# ADAPTER_PATH=/content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup/gemma-3-1b-it-lora-20260114-034307
# BASE_MODEL_ID=google/gemma-3-1b-it

# %%
# !ls -lah /content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup/gemma-3-1b-it-lora-20260114-034307 | head -n 50
# !ls -lah /content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup/gemma-3-1b-it-lora-20260114-034307/checkpoint-6001 | head -n 50
# Out:
# total 63M
# -rw------- 1 root root 1.1K Jan 14 09:19 adapter_config.json
# -rw------- 1 root root  25M Jan 14 09:19 adapter_model.safetensors
# -rw------- 1 root root   35 Jan 14 09:19 added_tokens.json
# -rw------- 1 root root 1.5K Jan 14 09:19 chat_template.jinja
# drwx------ 2 root root 4.0K Jan 14 04:39 checkpoint-1000
# drwx------ 2 root root 4.0K Jan 14 04:50 checkpoint-1200
# drwx------ 2 root root 4.0K Jan 14 05:01 checkpoint-1400
# drwx------ 2 root root 4.0K Jan 14 05:13 checkpoint-1600
# drwx------ 2 root root 4.0K Jan 14 05:24 checkpoint-1800
# drwx------ 2 root root 4.0K Jan 14 03:54 checkpoint-200
# drwx------ 2 root root 4.0K Jan 14 05:35 checkpoint-2000
# drwx------ 2 root root 4.0K Jan 14 05:46 checkpoint-2200
# drwx------ 2 root root 4.0K Jan 14 05:57 checkpoint-2400
# drwx------ 2 root root 4.0K Jan 14 06:09 checkpoint-2600
# drwx------ 2 root root 4.0K Jan 14 06:20 checkpoint-2800
# drwx------ 2 root root 4.0K Jan 14 06:31 checkpoint-3000
# ...
