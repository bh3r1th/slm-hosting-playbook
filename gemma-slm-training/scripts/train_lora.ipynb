# %%
# !git clone https://github.com/bh3r1th/slm-hosting-playbook.git
# Out:
# Cloning into 'slm-hosting-playbook'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 200 (delta 22), reused 26 (delta 11), pack-reused 158 (from 2)
# Receiving objects: 100% (200/200), 6.78 MiB | 20.17 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd slm-hosting-playbook/gemma-slm-training
# Out:
# /content/slm-hosting-playbook/gemma-slm-training

# %%
# !pip -q install -e .
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 kB 48.1 MB/s eta 0:00:00
#   Building editable for gemma-slm-training (pyproject.toml) ... done

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %%bash
# set -e
#
# BACKUP_DIR="/content/drive/MyDrive/slm-hosting-playbook-artifacts/live_backup"
# SRC_DIR="/content/slm-hosting-playbook/gemma-slm-training/artifacts"
#
# mkdir -p "$BACKUP_DIR"
#
# ( while true; do
#     stdbuf -oL -eL echo "[sync] $(date) syncing artifacts to Drive..."
#     rsync -a --partial --inplace "$SRC_DIR"/ "$BACKUP_DIR"/ || true
#     stdbuf -oL -eL echo "[sync] $(date) done"
#     sleep 120
#   done ) &
#
# cd /content/slm-hosting-playbook/gemma-slm-training
# stdbuf -oL -eL python -u scripts/train_lora.py --qlora --epochs 1 --max-seq-len 1024
#
# echo "[sync] final sync..."
# rsync -a "$SRC_DIR"/ "$BACKUP_DIR"/ || true
# echo "Backup complete: $BACKUP_DIR"
# Out:
# Process is interrupted.
